# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.available
plt.style.use('seaborn-whitegrid')
# Out:
# C:\Users\lamvu\AppData\Local\Temp\ipykernel_27488\1607254196.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
df1 = pd.read_csv("japan_gdp.csv")  # read file 1
df1.head(1000)
# Out:
#           Entity Code  Year          GDP 417484-annotations
# 0    Afghanistan  AFG  1950   9421400000                NaN
# 1    Afghanistan  AFG  1951   9692280000                NaN
# 2    Afghanistan  AFG  1952  10017325000                NaN
# 3    Afghanistan  AFG  1953  10630520000                NaN
# 4    Afghanistan  AFG  1954  10866360000                NaN
# ..           ...  ...   ...          ...                ...
# 995     Barbados  BRB  1966   1622028000                NaN
# 996     Barbados  BRB  1967   1783096000                NaN
# 997     Barbados  BRB  1968   2022960000                NaN
# 998     Barbados  BRB  1969   2210033000                NaN
# 999     Barbados  BRB  1970   2437083000                NaN
#
# [1000 rows x 5 columns]

# %%
df_japan = df1[(df1['Entity']=='Japan') & (df1['Year']>=1960) ]
df_america = df1[(df1['Entity']=='United States') & (df1['Year']>=1960) ]
df_Russia = df1[(df1['Entity']=='Russia') & (df1['Year']>=1960) ]
df_Russia
# Out:
#        Entity Code  Year            GDP 417484-annotations
# 11484  Russia  RUS  1960   664793000000                NaN
# 11485  Russia  RUS  1961   712659240000                NaN
# 11486  Russia  RUS  1962   765404300000                NaN
# 11487  Russia  RUS  1963   795991100000                NaN
# 11488  Russia  RUS  1964   847772250000                NaN
# 11489  Russia  RUS  1965   894393840000                NaN
# 11490  Russia  RUS  1966   957776860000                NaN
# 11491  Russia  RUS  1967  1018164400000                NaN
# 11492  Russia  RUS  1968  1081402700000                NaN
# 11493  Russia  RUS  1969  1109530400000                NaN
# 11494  Russia  RUS  1970  1202686800000                NaN
# 11495  Russia  RUS  1971  1253060900000                NaN
# 11496  Russia  RUS  1972  1289356600000                NaN
# 11497  Russia  RUS  1973  1390779400000                NaN
# 11498  Russia  RUS  1974  1440623100000                NaN
# ...

# %%
plt.plot(df_japan["Year"], df_japan["GDP"]/100000000, color="blue", label="GDP_Japan");
plt.plot(df_america["Year"], df_america["GDP"]/100000000, color="red", label="GDP_USA");
plt.plot(df_Russia["Year"], df_Russia["GDP"]/100000000, color="green", label="GDP_Russia");

plt.axis("tight")
plt.title ("GPD Japan")

plt.legend();


plt.xlabel("Year");
plt.ylabel("GDP (x 100 million)");
